# %%
import os
import pandas as pd
import numpy as np

path = 'C:/Users/Leand/OneDrive/Documentos/Lean/Analizador_imagenes_calcio/seleccion/010719SEL/'

dirlist = [ item for item in os.listdir(path) if os.path.isdir(os.path.join(path, item)) ]
for folder in dirlist:
    csv_list = os.listdir(path + folder + '/')
    csv_list = [x.split('.')[0] for x in csv_list if 'csv' in x if 'ratio' not in x]

    df = pd.DataFrame ()
    for table in csv_list:
        tabla = pd.read_csv(path + folder + '/' + table + '.csv',index_col=0, encoding='utf-8')
        tabla [table] = np.where(tabla['Pico_0'] < tabla['Pico_1'], tabla['Pico_1'], tabla['Pico_0'])
        df = pd.concat([df.reset_index(drop=True), tabla.reset_index(drop=True)], axis=1)
    df.to_csv(path + folder + '/' + 'ampratio_' + folder + '.csv',sep="\t", decimal=',')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\PyMOL\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pico_0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-514b7a2b51de> in <module>
#      13     for table in csv_list:
# ...

# %%
import os
import pandas as pd
import numpy as np

path = 'C:/Users/Leand/OneDrive/Documentos/Lean/Analizador_imagenes_calcio/seleccion/010819Sel/'
df = pd.DataFrame ()
dirlist = [ item for item in os.listdir(path) if os.path.isdir(os.path.join(path, item)) ]
for folder in dirlist:
    csv_list = os.listdir(path + folder + '/')
    csv_list = [x.split('.')[0] for x in csv_list if 'csv' in x if 'ratio' in x]
    for table in csv_list:
        tabla = pd.read_csv(path + folder + '/' + table + '.csv', sep='\t')
        tabla = tabla['Pico_1/Pico_0']
        df [table] = tabla
df.to_csv(path + 'ampratio.csv',sep="\t", decimal=',')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\PyMOL\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pico_1/Pico_0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-343416571949> in <module>
#      11     for table in csv_list:
# ...

# %%
df.describe()
# Out:
#        amplitudes_ratio_c1a000 amplitudes_ratio_c1b000  \
# count                       42                      34
# unique                      42                      34
# top         0,9197883597883598      1,0380356283100625
# freq                         1                       1
#
#        amplitudes_ratio_c1c000 amplitudes_ratio_c1d000  \
# count                       34                      32
# unique                      34                      32
# top          0,945409429280397      1,0636363636363637
# freq                         1                       1
#
#        amplitudes_ratio_c6a000 amplitudes_ratio_c6b000  \
# count                       39                      39
# unique                      39                      39
# top         1,1153846153846154       1,028169014084507
# freq                         1                       1
#
#        amplitudes_ratio_c6c000 amplitudes_ratio_c6d000  \
# count                       37                      37
# ...

# %%
import os
import pandas as pd
import numpy as np
means = pd.DataFrame ()
path = 'C:/Users/Leand/OneDrive/Documentos/Lean/Analizador_imagenes_calcio/seleccion/'
listlistdir = [ item for item in os.listdir(path) if os.path.isdir(os.path.join(path, item)) ]
for i in listlistdir:
    dirlist = [ item for item in os.listdir(path+ i + '/') if os.path.isdir(os.path.join(path+ i + '/', item)) ]
    for folder in dirlist[:]:
        csv_list = os.listdir(path + i + '/' + folder + '/')
        lista_foto = [x.split('.')[0] for x in csv_list if 'txt' in x if 'Tabla_general' in x]
        for foto in lista_foto:
            tabla = open(path + i + '/' + folder + '/' + foto + '.txt', 'r').read().split('\"')
            taus = []
            for j in tabla:
                j = j.split(',')
                taus_frame = []
                for item in range(8,len(j),8):
                    try:
                        tau = float(j[item].replace(']',''))
                        taus.append(tau)
                    except ValueError:
                        tau = (j[item].replace(']',''))
                        taus.append(tau)
            Columns = ['Transient_' + str(j) for j in range(-1,5)]
            subList = [taus[n:n+6] for n in range(0, len(taus), 6)]
            df = pd.DataFrame(subList, columns = Columns)
            df = df[df.columns.drop('Transient_-1')]
            df.loc['mean'] = df.mean()
#             df.to_csv(path + i + '/' + folder + '/' + 'tau_' + folder + foto + '.csv',sep="\t", decimal=',')
            listapromedio.append (promedio)

# %%
print (means)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

path_imagenes = '/media/leandro/Volumen1TB/Lean/Analizador_imagenes_calcio/Luis/seleccion/'
df_tabulado = pd.read_csv(path_imagenes + 'tabulado_imagenes.csv', index_col= 'Unnamed: 0')
path = '/media/leandro/Volumen1TB/Lean/Analizador_imagenes_calcio/Luis/analisis/whole_cell/'
lista = pd.read_csv(path+'tau_wc.csv',sep='\t', decimal=',', index_col='Unnamed: 0')

# %%
lista.head()
# Out:
#                                      file         tau
# 0     311019_analysis_result_vk2b000.json   41.105514
# 1      171019_analysis_result_c1c000.json   36.645964
# 2  230819VK1_analysis_result_vk1c000.json  164.000044
# 3     200121_analysis_result_vk2b000.json  208.133972
# 4      030321_analysis_result_D6c000.json   61.874886

# %%
df = []
for trat in ['c','vk','d']:
    for frec in [1,3,4,5]:
        df.append([trat,frec,None])
        controles = df_tabulado[(df_tabulado['tratamiento']==trat)&(df_tabulado['frecuencia']==frec)]
        for i in range(len(lista['file'])):
            file = lista['file'][i]
            experiment = file.split('_')[0][:6]
            photo = file.split('_')[-1].split('.')[0]
            if ((int(experiment) in list(controles['experimento'])) & (photo in list(controles['foto']))):
                df.append([experiment, photo,lista['tau'][i]])
            else:
                pass

# %%
df = pd.DataFrame(df)

# %%
df.to_csv('/media/leandro/Volumen1TB/Lean/Analizador_imagenes_calcio/Luis/analisis/whole_cell/tau.csv',sep='\t',decimal=',')

# %%
df
# Out:
#           0         1           2
# 0         c         1         NaN
# 1    050320     8b000  148.266447
# 2    200121    c3a000  260.986511
# 3    010719  ctrol8b0    4.707656
# 4    171019    c1a000  124.120197
# ..      ...       ...         ...
# 640  171019  dan4d000    4.297848
# 641  240221    D3d000   36.022035
# 642  200121    d2d000  194.718419
# 643  060121    d5d000   78.447422
# 644  060121    d7d001   70.061763
#
# [645 rows x 3 columns]
