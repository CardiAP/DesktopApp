# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Leand/OneDrive/Documentos/Lean/Analizador_imagenes_calcio/Luis/discordances_indexes.csv", sep="\t")

# %%
#df2 = df.groupby(by="Tratamiento")

# %%
df
# Out:
#      Unnamed: 0                                  photo_name        DI  \
# 0             0  010719ctrol1_analysis_result_ctrol1a0.json  0.060065
# 1             1  010719ctrol1_analysis_result_ctrol1b0.json  0.698376
# 2             2  010719ctrol8_analysis_result_ctrol8a0.json  0.336013
# 3             3  010719ctrol8_analysis_result_ctrol8b0.json  0.100734
# 4             4    010719Dan2_analysis_result_dan2a000.json  0.079469
# ..          ...                                         ...       ...
# 129         137    311019dan5_analysis_result_dan5d000.json  0.241153
# 130         138      311019vk2_analysis_result_vk2a000.json  0.088443
# 131         139      311019vk2_analysis_result_vk2d000.json  0.192759
# 132         140      311019vk4_analysis_result_vk4a000.json  0.070853
# 133         141      311019vk4_analysis_result_vk4d000.json  0.353582
#
#      Frecuencia Tratamiento
# 0             1           C
# 1             5           C
# 2             5           C
# 3             1           C
# 4             1           D
# ..          ...         ...
# 129           5           D
# 130           1           V
# 131           5           V
# 132           1           V
# 133           5           V
#
# [134 rows x 5 columns]

# %%
ax = sns.scatterplot(x="AR", y="Tratamiento", hue="Frecuencia", data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))


sns.boxplot(x="DI", y="Tratamiento", hue="Frecuencia", data=df)

sns.swarmplot(x="DI", y="Tratamiento", hue="Frecuencia", data=df, linewidth=2)
# plt.savefig('AR')
# Out:
# C:\Users\Leand\PyMOL\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\Leand\PyMOL\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="ticks")

sns.catplot(x="DI", y="Tratamiento", hue="Frecuencia", data=df, linewidth=1, kind="swarm")

sns.catplot(x="DI", y="Tratamiento", hue="Frecuencia", data=df, kind="box")
# plt.savefig('AR1')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

ax = sns.boxplot(x="DI", y="Tratamiento", hue="Frecuencia", data=df)
ax = sns.swarmplot(x="DI", y="Tratamiento", hue="Frecuencia", data=df, color=".25")

plt.show()
