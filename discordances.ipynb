# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Leand/OneDrive/Documentos/Lean/Analizador_imagenes_calcio/Luis/alternance_ratio.csv", sep="\t")

# %%
#df2 = df.groupby(by="Tratamiento")

# %%
df.head()
# Out:
#    Unnamed: 0                                  photo_name     tau_wc  \
# 0           0  010719ctrol1_analysis_result_ctrol1a0.json  10.176169
# 1           1  010719ctrol1_analysis_result_ctrol1b0.json   5.816331
# 2           2  010719ctrol8_analysis_result_ctrol8a0.json   6.178147
# 3           3  010719ctrol8_analysis_result_ctrol8b0.json   4.707656
# 4           4    010719Dan2_analysis_result_dan2a000.json   5.931059
#
#    tau_slices  Frecuencia Tratamiento
# 0   10.395947         1.0           C
# 1    5.352654         5.0           C
# 2    6.210884         5.0           C
# 3    4.711333         1.0           C
# 4    5.912067         1.0           D

# %%
ax = sns.scatterplot(x="AR", y="Tratamiento", hue="Frecuencia", data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))


sns.boxplot(x="AR", y="Tratamiento", hue="Frecuencia", data=df)

sns.swarmplot(x="AR", y="Tratamiento", hue="Frecuencia", data=df, linewidth=2)
plt.savefig('AR')
# Out:
# C:\Users\Leand\PyMOL\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\Leand\PyMOL\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="ticks")

sns.catplot(x="AR", y="Tratamiento", hue="Frecuencia", data=df, linewidth=1, kind="swarm")

sns.catplot(x="AR", y="Tratamiento", hue="Frecuencia", data=df, kind="box")
plt.savefig('AR1')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

ax = sns.boxplot(x="DI", y="Tratamiento", hue="Frecuencia", data=df)
ax = sns.swarmplot(x="DI", y="Tratamiento", hue="Frecuencia", data=df, color=".25")

plt.show()
